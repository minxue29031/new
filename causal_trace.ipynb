# %%
IS_COLAB = False

# %% [markdown]
# ## Causal Tracing
#
# A demonstration of the double-intervention causal tracing method.
#
# The strategy used by causal tracing is to understand important
# states within a transfomer by doing two interventions simultaneously:
#
# 1. Corrupt a subset of the input.  In our paper, we corrupt the subject tokens
#    to frustrate the ability of the transformer to accurately complete factual
#    prompts about the subject.
# 2. Restore a subset of the internal hidden states.  In our paper, we scan
#    hidden states at all layers and all tokens, searching for individual states
#    that carry the necessary information for the transformer to recover its
#    capability to complete the factual prompt.
#
# The traces of decisive states can be shown on a heatmap.  This notebook
# demonstrates the code for conducting causal traces and creating these heatmaps.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# The `experiments.causal_trace` module contains a set of functions for running causal traces.
#
# In this notebook, we reproduce, demonstrate and discuss the interesting functions.
#
# We begin by importing several utility functions that deal with tokens and transformer models.

# %%
import os
os.chdir("..")

# %%
import os, re, json
import torch, numpy
from tqdm import tqdm
from collections import defaultdict
from util import nethook
from util.globals import DATA_DIR
from experiments.causal_trace import (
    ModelAndTokenizer,
    layername,
    guess_subject,
    plot_trace_heatmap,
)
from experiments.causal_trace import (
    make_inputs,
    decode_tokens,
    find_token_range,
    predict_token,
    predict_from_input,
    collect_embedding_std,
)
from dsets import KnownsDataset

torch.set_grad_enabled(False)
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-uw00lo__ because the default path (/nfs/home/eimgrund_msc2023/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# Now we load a model and tokenizer, and show that it can complete a couple factual statements correctly.

# %%
model_name = "codellama/CodeLlama-7b-hf"

# %%
model_name = "codellama/CodeLlama-7b-Instruct-hf"

# %%
model_name = "meta-llama/Llama-2-7b-hf"

# %%
model_name = "mistralai/Mistral-7B-v0.1"

# %%
mt = ModelAndTokenizer(
    model_name,
    low_cpu_mem_usage=False,
    torch_dtype=torch.float16,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
predict_token(
    mt,
    ["Megan Rapinoe plays the sport of", "The Space Needle is in the city of", "def fibo(n"],
    return_p=True,
)
# Out:
# (['her', 'New', '):'], tensor([0.4109, 0.0280, 0.7834], device='cuda:0'))

# %%
"""void insertionsort(int *const data, size_t const n) {
	size_t i;
	for (i = 1; i < n; ++i) {
		int tmp = data[i];
		size_t j = i;
		while (j > 0 && tmp < data[j-1]) {
			data[j] = data[j-1];
			--j;
		}
		data[j] = tmp;
	}
}"""
predict_token(
    mt,
    ["""void insertionsort(int *const data, size_t const n) {
	size_t i;
	for (i = 1; i < n; ++i) {
		int tmp = data[i];
		size_t j = i;
		while (j > 0 && data[j-1] > """],
    return_p=True,
)
# Out:
# (['tmp'], tensor([0.6001], device='cuda:0'))

# %%
prompt = """[INST] You are a code completion tool. Complete the following Python tool. Only provide the completed code. Do not return descriptions of your actions.
[/INST]
from pydantic import BaseModel
# Complete class User, create an instance and then convert to a dict

class User(BaseModel):
    name: str
    age: int

user = User(name="John", age=30)
user_dict = user."""
predict_token(
    mt,
    [prompt],
    return_p=True,
)
# Out:
# (['dict'], tensor([0.9801], device='cuda:0'))

# %% [markdown]
# To obfuscate the subject during Causal Tracing, we use noise sampled from a zero-centered spherical Gaussian, whose stddev is 3 times the $\sigma$ stddev the model's embeddings. Let's compute that value.

# %%
knowns = KnownsDataset(DATA_DIR)  # Dataset of known facts
noise_level = 3 * collect_embedding_std(mt, [k["subject"] for k in knowns])
print(f"Using noise level {noise_level}")
# Out:
# Loaded dataset with 1209 elements
# Using noise level 0.0612030029296875

# %% [markdown]
# ## Tracing a single location
#
# The core intervention in causal tracing is captured in this function:
#
# `trace_with_patch` a single causal trace.
#
# It enables running a batch of inferences with two interventions.
#
#   1. Random noise can be added to corrupt the inputs of some of the batch.
#   2. At any point, clean non-noised state can be copied over from an
#      uncorrupted batch member to other batch members.
#
# The convention used by this function is that the zeroth element of the
# batch is the uncorrupted run, and the subsequent elements of the batch
# are the corrupted runs.  The argument tokens_to_mix specifies an
# be corrupted by adding Gaussian noise to the embedding for the batch
# inputs other than the first element in the batch.  Alternately,
# subsequent runs could be corrupted by simply providing different
# input tokens via the passed input batch.
#
# To ensure that corrupted behavior is representative, in practice, we
# will actually run several (ten) corrupted runs in the same batch,
# each with its own sample of noise.
#
# Then when running, a specified set of hidden states will be uncorrupted
# by restoring their values to the same vector that they had in the
# zeroth uncorrupted run.  This set of hidden states is listed in
# states_to_patch, by listing [(token_index, layername), ...] pairs.
# To trace the effect of just a single state, this can be just a single
# token/layer pair.  To trace the effect of restoring a set of states,
# any number of token indices and layers can be listed.
#
# Note that this function is also in experiments.causal_trace; the code
# is shown here to show the logic.

# %%
def trace_with_patch(
    model,  # The model
    inp,  # A set of inputs
    states_to_patch,  # A list of (token index, layername) triples to restore
    answers_t,  # Answer probabilities to collect
    tokens_to_mix,  # Range of tokens to corrupt (begin, end)
    noise=0.1,  # Level of noise to add
    trace_layers=None,  # List of traced outputs to return
):
    prng = numpy.random.RandomState(1)  # For reproducibility, use pseudorandom noise
    patch_spec = defaultdict(list)
    for t, l in states_to_patch:
        patch_spec[l].append(t)
    embed_layername = layername(model, 0, "embed")

    def untuple(x):
        return x[0] if isinstance(x, tuple) else x

    # Define the model-patching rule.
    def patch_rep(x, layer):
        if layer == embed_layername:
            # If requested, we corrupt a range of token embeddings on batch items x[1:]
            if tokens_to_mix is not None:
                b, e = tokens_to_mix
                x[1:, b:e] += noise * torch.from_numpy(
                    prng.randn(x.shape[0] - 1, e - b, x.shape[2])
                ).to(x.device)
            return x
        if layer not in patch_spec:
            return x
        # If this layer is in the patch_spec, restore the uncorrupted hidden state
        # for selected tokens.
        h = untuple(x)
        for t in patch_spec[layer]:
            h[1:, t] = h[0, t]
        return x

    # With the patching rules defined, run the patched model in inference.
    additional_layers = [] if trace_layers is None else trace_layers
    with torch.no_grad(), nethook.TraceDict(
        model,
        [embed_layername] + list(patch_spec.keys()) + additional_layers,
        edit_output=patch_rep,
    ) as td:
        outputs_exp = model(**inp)

    # We report softmax probabilities for the answers_t token predictions of interest.
    probs = torch.softmax(outputs_exp.logits[1:, -1, :], dim=1).mean(dim=0)[answers_t]

    # If tracing all layers, collect all activations together to return.
    if trace_layers is not None:
        all_traced = torch.stack(
            [untuple(td[layer].output).detach().cpu() for layer in trace_layers], dim=2
        )
        return probs, all_traced

    return probs

# %% [markdown]
# ## Scanning all locations
#
# A causal flow heatmap is created by repeating `trace_with_patch` at every individual hidden state, and measuring the impact of restoring state at each location.
#
# The `calculate_hidden_flow` function does this loop.  It handles both the case of restoring a single hidden state, and also restoring MLP or attention states.  Because MLP and attention make small residual contributions, to observe a causal effect in those cases, we need to restore several layers of contributions at once, which is done by `trace_important_window`.

# %%
def calculate_hidden_flow(
    mt, prompt, subject, samples=10, noise=0.1, window=10, kind=None
):
    """
    Runs causal tracing over every token/layer combination in the network
    and returns a dictionary numerically summarizing the results.
    """
    inp = make_inputs(mt.tokenizer, [prompt] * (samples + 1))
    with torch.no_grad():
        answer_t, base_score = [d[0] for d in predict_from_input(mt.model, inp)]
    [answer] = decode_tokens(mt.tokenizer, [answer_t])
    e_range = find_token_range(mt.tokenizer, inp["input_ids"][0], subject)
    low_score = trace_with_patch(
        mt.model, inp, [], answer_t, e_range, noise=noise
    ).item()
    if not kind:
        differences = trace_important_states(
            mt.model, mt.num_layers, inp, e_range, answer_t, noise=noise
        )
    else:
        differences = trace_important_window(
            mt.model,
            mt.num_layers,
            inp,
            e_range,
            answer_t,
            noise=noise,
            window=window,
            kind=kind,
        )
    differences = differences.detach().cpu()
    return dict(
        scores=differences,
        low_score=low_score,
        high_score=base_score,
        input_ids=inp["input_ids"][0],
        input_tokens=decode_tokens(mt.tokenizer, inp["input_ids"][0]),
        subject_range=e_range,
        answer=answer,
        window=window,
        kind=kind or "",
    )


def trace_important_states(model, num_layers, inp, e_range, answer_t, noise=0.1):
    ntoks = inp["input_ids"].shape[1]
    table = []
    for tnum in tqdm(range(ntoks), total=ntoks):
        row = []
        for layer in range(0, num_layers):
            r = trace_with_patch(
                model,
                inp,
                [(tnum, layername(model, layer))],
                answer_t,
                tokens_to_mix=e_range,
                noise=noise,
            )
            row.append(r)
        table.append(torch.stack(row))
    return torch.stack(table)


def trace_important_window(
    model, num_layers, inp, e_range, answer_t, kind, window=10, noise=0.1
):
    ntoks = inp["input_ids"].shape[1]
    table = []
    for tnum in tqdm(range(ntoks), total=ntoks):
        row = []
        for layer in range(0, num_layers):
            layerlist = [
                (tnum, layername(model, L, kind))
                for L in range(
                    max(0, layer - window // 2), min(num_layers, layer - (-window // 2))
                )
            ]
            r = trace_with_patch(
                model, inp, layerlist, answer_t, tokens_to_mix=e_range, noise=noise
            )
            row.append(r)
        table.append(torch.stack(row))
    return torch.stack(table)

# %% [markdown]
# ## Plotting the results
#
# The `plot_trace_heatmap` function draws the data on a heatmap.  That function is not shown here; it is in `experiments.causal_trace`.

# %%
def plot_hidden_flow(
    mt,
    prompt,
    subject=None,
    samples=10,
    noise=0.1,
    window=10,
    kind=None,
    modelname=None,
    savepdf=None,
):
    if subject is None:
        subject = guess_subject(prompt)
    result = calculate_hidden_flow(
        mt, prompt, subject, samples=samples, noise=noise, window=window, kind=kind
    )
    plot_trace_heatmap(result, savepdf, modelname=modelname)
    return result


def plot_all_flow(mt, prompt, subject=None, noise=0.1, modelname=None):
    for kind in [None, "mlp", "attn"]:
        plot_hidden_flow(
            mt, prompt, subject, modelname=modelname, noise=noise, kind=kind
        )

# %% [markdown]
# The following prompt can be changed to any factual statement to trace.

# %%
plot_all_flow(mt, "The Space Needle is in the city of", noise=noise_level)
# Out:
# 100%|██████████| 10/10 [00:12<00:00,  1.29s/it]
# 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]

# %%
result_mlp = plot_hidden_flow(mt, prompt, subject="User", noise=noise_level, kind="mlp")
# Out:
# 100%|██████████| 100/100 [13:56<00:00,  8.37s/it]

# %%
for i in torch.topk(torch.mean(result_mlp["scores"], dim=1), k=10).indices:
    print(i.item(), result_mlp["input_tokens"][i-1], result_mlp["input_tokens"][i], result_mlp["input_tokens"][i+1])
# Out:
# 93 ) <0x0A> user
# 79 <0x0A> <0x0A> user
# 98 ▁= ▁user .
# 65 ( Base Model
# 55 ▁and ▁then ▁convert
# 92 0 ) <0x0A>
# 67 Model ): <0x0A>
# 64 ▁User ( Base
# 62 <0x0A> class ▁User
# 97 dict ▁= ▁user

# %%
result_full = plot_hidden_flow(mt, prompt, subject="BaseModel", noise=noise_level, kind=None)
# Out:
# 100%|██████████| 100/100 [13:58<00:00,  8.39s/it]

# %%
for i in torch.topk(torch.mean(result_full["scores"], dim=1), k=10).indices:
    print(i.item(), result_full["input_tokens"][max(0, i-1)], result_full["input_tokens"][i], result_full["input_tokens"][min(i+1, len(result_full["input_tokens"])-1)])
# Out:
# 99 ▁user . .
# 41 yd antic ▁import
# 42 antic ▁import ▁Base
# 66 Base Model ):
# 45 Model <0x0A> #
# 43 ▁import ▁Base Model
# 59 ▁a ▁dict <0x0A>
# 65 ( Base Model
# 98 ▁= ▁user .
# 44 ▁Base Model <0x0A>

# %%
plot_all_flow(mt, prompt, subject="user", noise=noise_level)
# Out:
# 100%|██████████| 100/100 [14:02<00:00,  8.42s/it]
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
#  16%|█▌        | 16/100 [02:17<12:00,  8.58s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plot_all_flow(mt, prompt, subject="user", noise=noise_level)
#
# Cell In[11], line 22, in plot_all_flow(mt, prompt, subject, noise, modelname)
#      20 def plot_all_flow(mt, prompt, subject=None, noise=0.1, modelname=None):
#      21     for kind in [None, "mlp", "attn"]:
# ---> 22         plot_hidden_flow(
#      23             mt, prompt, subject, modelname=modelname, noise=noise, kind=kind
#      24         )
#
# Cell In[11], line 14, in plot_hidden_flow(mt, prompt, subject, samples, noise, window, kind, modelname, savepdf)
#      12 if subject is None:
#      13     subject = guess_subject(prompt)
# ---> 14 result = calculate_hidden_flow(
#      15     mt, prompt, subject, samples=samples, noise=noise, window=window, kind=kind
#      16 )
#      17 plot_trace_heatmap(result, savepdf, modelname=modelname)
#
# Cell In[10], line 21, in calculate_hidden_flow(mt, prompt, subject, samples, noise, window, kind)
#      17     differences = trace_important_states(
#      18         mt.model, mt.num_layers, inp, e_range, answer_t, noise=noise
#      19     )
#      20 else:
# ---> 21     differences = trace_important_window(
#      22         mt.model,
#      23         mt.num_layers,
#      24         inp,
#      25         e_range,
#      26         answer_t,
#      27         noise=noise,
#      28         window=window,
#      29         kind=kind,
#      30     )
#      31 differences = differences.detach().cpu()
#      32 return dict(
#      33     scores=differences,
#      34     low_score=low_score,
#    (...)
#      41     kind=kind or "",
#      42 )
#
# Cell In[10], line 78, in trace_important_window(model, num_layers, inp, e_range, answer_t, kind, window, noise)
#      71 for layer in range(0, num_layers):
#      72     layerlist = [
#      73         (tnum, layername(model, L, kind))
#      74         for L in range(
#      75             max(0, layer - window // 2), min(num_layers, layer - (-window // 2))
#      76         )
#      77     ]
# ---> 78     r = trace_with_patch(
#      79         model, inp, layerlist, answer_t, tokens_to_mix=e_range, noise=noise
#      80     )
#      81     row.append(r)
#      82 table.append(torch.stack(row))
#
# Cell In[9], line 48, in trace_with_patch(model, inp, states_to_patch, answers_t, tokens_to_mix, noise, trace_layers)
#      45     outputs_exp = model(**inp)
#      47 # We report softmax probabilities for the answers_t token predictions of interest.
# ---> 48 probs = torch.softmax(outputs_exp.logits[1:, -1, :], dim=1).mean(dim=0)[answers_t]
#      50 # If tracing all layers, collect all activations together to return.
#      51 if trace_layers is not None:
#
# KeyboardInterrupt:

# %%
plot_all_flow(mt, """void insertionsort(int *const data, size_t const n) {
	size_t i;
	for (i = 1; i < n; ++i) {
		int tmp = data[i];
		size_t j = i;
		while (j > 0 && data[j-1] > """, subject="data[j-1] > ", noise=noise_level)
# Out:
# 100%|██████████| 80/80 [09:43<00:00,  7.29s/it]
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 100%|██████████| 80/80 [09:47<00:00,  7.35s/it]
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 100%|██████████| 80/80 [09:47<00:00,  7.35s/it]
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plot_all_flow(mt, "def fibo(n):\n      return fibo(n - 1) + fibo(n - ", subject="fibo(n - 1) + fibo(n - ", noise=noise_level)
# Out:
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plot_all_flow(mt, "def fibo(n", noise=noise_level, subject="def")
# Out:
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Here we trace a few more factual statements from a file of test cases.

# %%
for knowledge in knowns[:5]:
    plot_all_flow(mt, knowledge["prompt"], knowledge["subject"], noise=noise_level)
# Out:
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /nfs/home/eimgrund_msc2023/.conda/envs/huge-models/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9601 (\N{LOWER ONE EIGHTH BLOCK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
